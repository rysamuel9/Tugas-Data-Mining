# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np


import seaborn as sns
sns.set()

# %%
# dataset = pd.read_csv('datamahasiswa.csv')
dataset = pd.read_excel('datamahasiswa.xlsx')

# %%
# value = dataset[['Nilai UTS', 'Nilai Tugas', 'Nilai UAS', 'Nilai Indeks']].describe()
# print(value.astype(int))

dataset.describe()
# Out:
#        Nomor Mahasiswa   Nilai UTS  Nilai Tugas   Nilai UAS
# count         20.00000   20.000000    20.000000   20.000000
# mean          10.50000   57.000000    64.750000   52.500000
# std            5.91608   15.508911    30.628289   29.580399
# min            1.00000   30.000000    10.000000    5.000000
# 25%            5.75000   48.750000    37.500000   28.750000
# 50%           10.50000   55.000000    80.000000   52.500000
# 75%           15.25000   65.000000    90.000000   76.250000
# max           20.00000  100.000000   100.000000  100.000000

# %%
dataset.head(20)
# Out:
#     Nomor Mahasiswa  Nilai UTS  Nilai Tugas  Nilai UAS Nilai Indeks
# 0                 1         30           10          5            E
# 1                 2         40           15         10            E
# 2                 3         40           20         15            E
# 3                 4         45           25         20            D
# 4                 5         45           30         25            D
# 5                 6         50           40         30            D
# 6                 7         50           50         35            D
# 7                 8         50           60         40            C
# 8                 9         50           70         45            C
# 9                10         50           80         50            C
# 10               11         60           80         55            C
# 11               12         60           85         60            C
# 12               13         60           85         65            C
# 13               14         65           85         70            B
# 14               15         65           90         75            B
# 15               16         65           90         80            B
# 16               17         70           90         85            B
# 17               18         70           95         90            A
# 18               19         75           95         95            A
# 19               20        100          100        100            A

# %%
# SCATTER #

dataset.plot.scatter(x='Nilai Tugas', y='Nomor Mahasiswa')
dataset.plot.scatter(x='Nilai UTS', y='Nomor Mahasiswa')
dataset.plot.scatter(x='Nilai UAS', y='Nomor Mahasiswa')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Nilai UAS', ylabel='Nomor Mahasiswa'>

# %%
# HISTOGRAM Nilai Tugas

dataset['Nilai Tugas'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# HISTOGRAM Nilai UTS

dataset['Nilai UTS'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# HISTOGRAM Nilai UTS

dataset['Nilai UAS'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import numpy as np 
import pylab as pl
import scipy.stats as stats

x = dataset['Nilai Tugas']  
y = dataset['Nilai UTS']  
z = dataset['Nilai UAS']  
stats.probplot(z, dist="norm", plot=pl)
# stats.probplot(y, dist="norm", plot=pl)
# stats.probplot(z, dist="norm", plot=pl)
pylab.show()
