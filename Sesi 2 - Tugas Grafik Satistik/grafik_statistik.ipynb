# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np


import seaborn as sns
sns.set()

# %%
# dataset = pd.read_csv('datamahasiswa.csv')
dataset = pd.read_excel('datamahasiswa.xlsx')

# %%
# value = dataset[['Nilai UTS', 'Nilai Tugas', 'Nilai UAS', 'Nilai Indeks']].describe()
# print(value.astype(int))

dataset.describe()
# Out:
#        Nomor Mahasiswa   Nilai UTS  Nilai Tugas   Nilai UAS
# count         20.00000   20.000000    20.000000   20.000000
# mean          10.50000   57.000000    64.750000   52.500000
# std            5.91608   15.508911    30.628289   29.580399
# min            1.00000   30.000000    10.000000    5.000000
# 25%            5.75000   48.750000    37.500000   28.750000
# 50%           10.50000   55.000000    80.000000   52.500000
# 75%           15.25000   65.000000    90.000000   76.250000
# max           20.00000  100.000000   100.000000  100.000000

# %%
dataset.head(20)
# Out:
#     Nomor Mahasiswa  Nilai UTS  Nilai Tugas  Nilai UAS Nilai Indeks
# 0                 1         30           10          5            E
# 1                 2         40           15         10            E
# 2                 3         40           20         15            E
# 3                 4         45           25         20            D
# 4                 5         45           30         25            D
# 5                 6         50           40         30            D
# 6                 7         50           50         35            D
# 7                 8         50           60         40            C
# 8                 9         50           70         45            C
# 9                10         50           80         50            C
# 10               11         60           80         55            C
# 11               12         60           85         60            C
# 12               13         60           85         65            C
# ...

# %%
# # MULTIPEL HISTOGRAM

# n_bins = 20
# # x = np.random.randn(1000, 3)
# nilai_tugas = dataset[['Nilai Tugas', 'Nilai UTS', 'Nilai UAS']]
# # nilai_uts = dataset['Nilai UTS']
# # nilai_uas = dataset['Nilai UAS']

# fig, ax0 = plt.subplots(nrows=1, ncols=1)

# colors = ['red', 'blue', 'green']
# labels = ['Nilai Tugas', 'Nilau UTS', 'Nilai UAS']
# ax0.hist(nilai_tugas, n_bins, density=True, histtype='bar', color=colors, label=labels)
# ax0.legend(prop={'size': 10})
# ax0.set_title('bars with legend')

# %%
# dataset[['Nilai UTS', 'Nilai UAS', 'Nilai Tugas']].plot.hist(bins=20, alpha=0.9)
dataset.plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataset.plot.scatter(y='Nomor Mahasiswa', x='Nilai Tugas')
dataset.plot.scatter(y='Nomor Mahasiswa', x='Nilai UTS')
dataset.plot.scatter(y='Nomor Mahasiswa', x='Nilai UAS')
# Out:
#   File "<ipython-input-35-2009eba48225>", line 1
#     dataset.plot.scatter(y='Nomor Mahasiswa', x='Nilai Tugas' cmap='ocean')
#                                                               ^
# SyntaxError: invalid syntax
