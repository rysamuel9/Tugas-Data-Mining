# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np


import seaborn as sns
sns.set()

# %%
# dataset = pd.read_csv('datamahasiswa.csv')
dataset = pd.read_excel('datamahasiswa.xlsx')

# %%
# value = dataset[['Nilai UTS', 'Nilai Tugas', 'Nilai UAS', 'Nilai Indeks']].describe()
# print(value.astype(int))
describe = dataset.describe()
describe.astype(int)
# Out:
#        Nomor Mahasiswa  Nilai UTS  Nilai Tugas  Nilai UAS
# count               20         20           20         20
# mean                10         57           64         52
# std                  5         15           30         29
# min                  1         30           10          5
# 25%                  5         48           37         28
# 50%                 10         55           80         52
# 75%                 15         65           90         76
# max                 20        100          100        100

# %%
dataset.head(20)
# Out:
#     Nomor Mahasiswa  Nilai UTS  Nilai Tugas  Nilai UAS Nilai Indeks
# 0                 1         30           10          5            E
# 1                 2         40           15         10            E
# 2                 3         40           20         15            E
# 3                 4         45           25         20            D
# 4                 5         45           30         25            D
# 5                 6         50           40         30            D
# 6                 7         50           50         35            D
# 7                 8         50           60         40            C
# 8                 9         50           70         45            C
# 9                10         50           80         50            C
# 10               11         60           80         55            C
# 11               12         60           85         60            C
# 12               13         60           85         65            C
# ...

# %%
# SCATTER #

dataset.plot.scatter(x='Nomor Mahasiswa', y='Nilai Tugas')
dataset.plot.scatter(x='Nomor Mahasiswa', y='Nilai UTS')
dataset.plot.scatter(x='Nomor Mahasiswa', y='Nilai UAS')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
# HISTOGRAM Nilai Tugas

dataset['Nilai Tugas'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# HISTOGRAM Nilai UTS

dataset['Nilai UTS'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# HISTOGRAM Nilai UTS

dataset['Nilai UAS'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import numpy as np 
import pylab as pl
import scipy.stats as stats

x = dataset['Nilai Tugas']  
y = dataset['Nilai UTS']  
z = dataset['Nilai UAS']  
stats.probplot(x, dist="norm", plot=pl)
stats.probplot(y, dist="norm", plot=pl)
# stats.probplot(z, dist="norm", plot=pl)
pl.show()
