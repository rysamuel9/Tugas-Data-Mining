# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

dataset = pd.read_excel("datamahasiswa.xlsx")
# dataset
# dataset.shape

# %%
set = dataset['Nilai UTS'].describe()
# list(set)
# Out:
# count     20.000000
# mean      57.000000
# std       15.508911
# min       30.000000
# 25%       48.750000
# 50%       55.000000
# 75%       65.000000
# max      100.000000
# Name: Nilai UTS, dtype: float64

# %%
nilai_min = dataset[['Nilai UTS', 'Nilai Tugas', 'Nilai UAS']].describe()

# %%
nilai_min.astype(int)
# Out:
#        Nilai UTS  Nilai Tugas  Nilai UAS
# count         20           20         20
# mean          57           64         52
# std           15           30         29
# min           30           10          5
# 25%           48           37         28
# 50%           55           80         52
# 75%           65           90         76
# max          100          100        100

# %%
dataset['Nilai UTS'].describe()
# Out:
# count     20.000000
# mean      57.000000
# std       15.508911
# min       30.000000
# 25%       48.750000
# 50%       55.000000
# 75%       65.000000
# max      100.000000
# Name: Nilai UTS, dtype: float64

# %%
xpoints = np.array([0, 20])
ypoints = np.array([0, 100])

plt.plot(xpoints, ypoints)

# %%
dataset['Nilai UTS'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
dataset['Nilai UTS'].hist()
# Out:
# <AxesSubplot:>

# %%
np.random.seed(1241241241)
N = 50
x = np.random(N)
y = np.random(N)
colors = np.random(N)
area = (30 * np.random.rand(N))**2

# %%
plt.scatter(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-1b0fed4705e5> in <module>
# ----> 1 scatter = dataset.scatter(x, y)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5459                 return self[name]
# -> 5460             return object.__getattribute__(self, name)
#    5461
#    5462     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'scatter'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-f29f9de9e0c6> in <module>
# ----> 1 dataset['Nilai UTS'].scatter()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5458             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5459                 return self[name]
# -> 5460             return object.__getattribute__(self, name)
#    5461
#    5462     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'scatter'
