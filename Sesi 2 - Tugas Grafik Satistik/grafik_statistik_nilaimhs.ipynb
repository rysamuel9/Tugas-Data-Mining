# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm


dataset = pd.read_excel("datamahasiswa.xlsx")
# dataset
# dataset.shape

# %%
dataset['Nilai UTS'].describe()
# list(set)
# Out:
# count     20.000000
# mean      57.000000
# std       15.508911
# min       30.000000
# 25%       48.750000
# 50%       55.000000
# 75%       65.000000
# max      100.000000
# Name: Nilai UTS, dtype: float64

# %%
nilai_min = dataset[['Nilai UTS', 'Nilai Tugas', 'Nilai UAS']].describe()

# %%
nilai_min.astype(int)
# Out:
#        Nilai UTS  Nilai Tugas  Nilai UAS
# count         20           20         20
# mean          57           64         52
# std           15           30         29
# min           30           10          5
# 25%           48           37         28
# 50%           55           80         52
# 75%           65           90         76
# max          100          100        100

# %%
dataset['Nilai UTS'].describe()
# Out:
# count     20.000000
# mean      57.000000
# std       15.508911
# min       30.000000
# 25%       48.750000
# 50%       55.000000
# 75%       65.000000
# max      100.000000
# Name: Nilai UTS, dtype: float64

# %%
plt.plot(xpoints, ypoints)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7df45603e5a9> in <module>
# ----> 1 plt.plot(xpoints, ypoints)
#
# NameError: name 'xpoints' is not defined

# %%
dataset[['Nilai UTS', 'Nilai Tugas', 'Nilai UAS']].plot()
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
dataset[['Nilai UTS', 'Nilai Tugas', 'Nilai UAS']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'Nilai UTS'}>,
#         <AxesSubplot:title={'center':'Nilai Tugas'}>],
#        [<AxesSubplot:title={'center':'Nilai UAS'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
n
# Out:
# Text(0.5, 1.0, 'bars with legend')
